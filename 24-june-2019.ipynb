# %% [markdown]
# ### working with random numbers and files
# - % of students passed
# - % of students failed
# - % of students with distinction

# %%
from random import randint
def generatemarks(n,lb,ub):

    for i in range(0,n,1):
        r=randint(lb,ub)
        f.write(r.__str__()+" ")

def passed_percentage(filename,marks):
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]>=Passmarks:
            count+=1
    print("Pass percentage is ",int((count/n)*100),"%")
    
def failed_percentage(filename,marks):
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]<Passmarks:
            count+=1
    print("fail percentage is ",int((count/n)*100),"%")

        
def distinction(filename,marks):
    count=0
    dist=int(input("Enter distinction marks lower bound  "))
    for i in range(0,len(marks),1):
        if marks[i]>=dist:
            count+=1
    print("distinction percentage is ",int((count/n)*100),"%")
    
def high_mark(marks):
    high=max(marks)
    count=0
    for i in range(0,len(marks),1):
        if marks[i]==high:
            count+=1
    print("Highest marks is ",high," number of persons got high",count)

def low_mark(marks):
    m=min(marks)
    count=0
    for i in range(0,len(marks),1):
        if marks[i]==m:
            count+=1
    print("Lowest marks is ",m," number of persons got low marks",count)
    

filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/marks.txt"
n=int(input("Enter how many student marks u want to geenrate "))
with open(filename,'r+') as f:
    generatemarks(n,0,100)
    
with open(filename,'r') as f:
    data=f.read()
    m=data.split(" ")
    marks=[]
    for i in range(0,len(m),1):
        marks=marks+[int(m[i])]
c=1
while c==1:
    print("\n1.List of marks\n2.Pass percentage\n3.Failed percentage\n4.Distinction percentage\n5.High marks\n6.Low mark\n")
    value=int(input())
    if value==1:
        for i in range(0,len(marks),1):
            print(marks[i],end=" ")
        
    elif value==2:
        passed_percentage(filename,marks)
    elif value==3:
        failed_percentage(filename,marks)
    elif value==4:
        distinction(filename,marks)
    elif value==5:
        high_mark(marks)
    elif value==6:
        low_mark(marks)
    else:
        print("\nWrong input.Please enter correct input\n")

    print("\nEnter 1 to continue\nEnter 0 to exit\n")
    c=int(input())
# Out:
# Enter how many student marks u want to geenrate 100
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
#
# 1
# 48 19 90 59 48 41 67 68 60 28 63 82 91 91 98 4 23 68 78 98 36 26 96 76 63 0 7 9 31 5 61 94 0 24 56 76 63 11 43 3 100 59 96 73 94 31 32 54 73 8 49 44 10 25 53 39 16 33 37 51 26 61 54 24 27 48 52 83 1 14 67 36 43 84 4 90 45 22 51 80 100 59 85 82 81 100 15 26 64 12 3 45 8 44 49 45 71 25 21 85 4 9
# Enter 1 to continue
# Enter 0 to exit
#
# 1
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
#
# 2
# Enter pass marks  35
# Pass percentage is  65 %
#
# Enter 1 to continue
# Enter 0 to exit
#
# 1
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
#
# 5
# Highest marks is  100  number of persons got high 3
#
# Enter 1 to continue
# Enter 0 to exit
#
# 1
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
#
# 6
# Lowest marks is  0  number of persons got low marks 2
#
# Enter 1 to continue
# Enter 0 to exit

# %%
from random import randint
def generatemarks(n,lb,ub):
    r=randint(lb,ub)
    f.write(r.__str__())
    for i in range(0,n-1,1):
        r=randint(lb,ub)
        f.write(" "+r.__str__())
        
def list_of_marks(filename):
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")
        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    print(marks)
    
def passed_percentage(filename):
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")

        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    count=0
    
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]>=Passmarks:
            count+=1
    print("Pass percentage is ",int((count/n)*100),"%")
def failed_percentage(filename):
    
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")

        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]<Passmarks:
            count+=1
    print("fail percentage is ",int((count/n)*100),"%")

        
def distinction(filename):
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")

        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    count=0
    dist=int(input("Enter distinction marks lower bound  "))
    for i in range(0,len(marks),1):
        if marks[i]>=dist:
            count+=1
    print("distinction percentage is ",int((count/n)*100),"%")
    
filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/marks.txt"
n=int(input("Enter how many student marks u want to geenrate "))
with open(filename,'r+') as f:
    generatemarks(n,0,100)
c=1
while c==1:
    print("\n1.List of marks\n2.Pass percentage\n3.Failed percentage\n4.Distinction percentage\n")
    value=int(input())
    if value==1:
        list_of_marks(filename)
    elif value==2:
        passed_percentage(filename)
    elif value==3:
        failed_percentage(filename)
    elif value==4:
        distinction(filename)
    else:
        print("\nWrong input.Please enter correct input\n")

    print("\nEnter 1 to continue\nEnter 0 to exit\n")
    c=int(input())

print(len(marks))
# Out:
# Enter how many student marks u want to geenrate 100
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
#
# 1
# [94, 47, 14, 21, 81, 0, 28, 44, 29, 14, 39, 24, 21, 100, 75, 3, 28, 40, 71, 85, 41, 21, 94, 44, 40, 56, 78, 56, 52, 7, 100, 47, 15, 45, 45, 53, 79, 62, 32, 92, 98, 37, 50, 70, 3, 90, 34, 70, 75, 39, 76, 81, 28, 68, 69, 30, 23, 15, 88, 41, 17, 29, 36, 80, 54, 49, 18, 17, 29, 15, 11, 56, 75, 92, 16, 32, 61, 45, 29, 50, 40, 96, 29, 78, 97, 61, 34, 36, 54, 95, 83, 71, 66, 12, 37, 22, 54, 95, 49, 676]
#
# Enter 1 to continue
# Enter 0 to exit
#
# 0
# 0
