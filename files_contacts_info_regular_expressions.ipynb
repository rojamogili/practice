# %% [markdown]
# - ^[6-9][0-9]{9}$|^[+][9][1][6-9][0-9]{9}$|^[0][6-9][0-9]{9}$  --> Regular expression for indian phone number validate
# - ^[a-zA-Z0-9][0-9a-zA-Z_.]{5,14}[0-9a-zA-Z](@)[0-9a-zA-Z]{2,15}(.)[a-z]{2,4}   ->Regular expression for email validator

# %%
# Contact List of user which validate phone number and email address using functions

import re
def PhoneNumber_validator(number):
    pattern='^[6-9][0-9]{9}$|^[+][9][1][6-9][0-9]{9}$|^[0][6-9][0-9]{9}$'
    if re.match(pattern,number):
        return True
    else:
        return False


def mail_validator(mail):
    pattern='^[a-zA-Z0-9][0-9a-zA-Z_.]{5,14}[0-9a-zA-Z](@)[0-9a-zA-Z]{2,15}(.)[a-z]{2,4}'
    if re.match(pattern,mail):
        return True
    else:
        return False

def add_contact(contact):
    con=[]
    name=input("Enter name of the contact  ")
    num=int(input("Enter the contact number  "))
    email=input("Enter email address  ")
    if mail_validator(email)==True:
        con=con+[email]
    else:
        print("Please enter correct email  ")
        email=input("Enter email address  ")
        con=con+[email]
    n=num.__str__()
    if PhoneNumber_validator(n)==True:
        con=con+[num]
        contact[name]=con
    else:
        print("Wrong contact Number.\nPlease enter correct number")
        num=int(input("Enter correct contact number  "))
        con=con+[num]
        contact[name]=con

def remove_contact(contact):
    name=input("Enter name to remove contact  ")
    contact.pop(name)
    
def update_contact(contact):
    name=input("Enter name to update contact and email")
    num=int(input("Enter number to update  "))
    email=input("Enter email address  ")
    if mail_validator(email)==True:
        con=con+[email]
    else:
        print("Please enter correct email  ")
        email=input("Enter email address  ")
        con=con+[email]
    n=num.__str__()
    if PhoneNumber_validator(n)==True:
        con=con+[num]
        contact[name]=con
    else:
        print("Wrong contact Number.\nPlease enter correct number")
        num=int(input("Enter correct contact number  "))
        con=con+[num]
        contact[name]=con
   
def search(contact):
    name=input("Enter name to search   ")
    print(contact[name])
    
def view_contact_list(contact):
    print("NAME\temail\t\t\tNumber")
    for key,value in contact.items():
        print(key,"\t",value[0]," \t",value[1])
        
def import_contacts(contact,import_con):
    contact.update(import_con)
    return contact        
        
contact={}
x=1
while x==1:
    print("1.Add contact\n2.Remove Contact\n3.Update Contact\n4.Search for contact\n5.view contact list\n6.import contact list")
    c=int(input())
    if c==1:
        add_contact(contact)
    elif c==2:
        remove_contact(contact)
    elif c==3:
        update_contact(contact)
    elif c==4:
        search(contact)
    elif c==5:
        view_contact_list(contact)
    elif c==6:
        import_con={'lally':['lally987654321@gmail.com',7032111051],'nani':['nani120519@gmail.com',9160298637]}
        import_contacts(contact,import_con)
    x=int(input("Enter 1 to continue\nEnter 0 to exit\n"))
# Out:
# 1.Add contact
# 2.Remove Contact
# 3.Update Contact
# 4.Search for contact
# 5.view contact list
# 6.import contact list
# 1
# Enter name of the contact  roja
# Enter the contact number  7032111051
# Enter email address  mogiliroja
# Please enter correct email
# Enter email address  mogiliroja@gmail.com
# Enter 1 to continue
# Enter 0 to exit
# 1
# 1.Add contact
# 2.Remove Contact
# 3.Update Contact
# 4.Search for contact
# 5.view contact list
# 6.import contact list
# 6
# Enter 1 to continue
# Enter 0 to exit
# 1
# 1.Add contact
# 2.Remove Contact
# 3.Update Contact
# 4.Search for contact
# 5.view contact list
# 6.import contact list
# 5
# NAME	email			Number
# roja 	 mogiliroja@gmail.com  	 7032111051
# lally 	 lally987654321@gmail.com  	 7032111051
# nani 	 nani120519@gmail.com  	 9160298637
# Enter 1 to continue
# Enter 0 to exit
# 0

# %%
# Funciton to add contact to contacts text file
#import email_validate
#import Phone_number_validator 

import re
def mail_validator(mail):
    pattern='^[a-zA-Z0-9][0-9a-zA-Z_.]{5,14}[0-9a-zA-Z](@)[0-9a-zA-Z]{2,15}(.)[a-z]{2,4}'
    if re.match(pattern,mail):
        return True
    else:
        return False
    
def PhoneNumber_validator(number):
    pattern='^[6-9][0-9]{9}$|^[+][9][1][6-9][0-9]{9}$|^[0][6-9][0-9]{9}$'
    if re.match(pattern,number):
        return True
    else:
        return False


def add_contact(name,phone,email):
    #store datas name, phone,email in the contact text file
    filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
    if not checkContactExists(name):
        p=phone.__str__()
        if PhoneNumber_validator(p)==True and mail_validator(email)==True:
            with open(filename,'a') as f:
                line=name+','+str(phone)+','+email
                f.write(line)
        print(name,'added to contact list')
    else:
        print(name,'already exists')
    return

#Function to check if contact already exists
def checkContactExists(name):
    filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
    with open(filename,'r') as f:
        data=f.read()
        pattern=name+','
    print(re.search(pattern,data))
    return re.search(name,data)

def search_contact(name):
    filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
    with open(filename,'r')as f:
        lines=f.readlines()
        pattern=name+","
        for name in lines:
            if re.search(pattern,name):
                print(name)
                
def list_of_contacts(filename):
    f=open(filename,'r')
    data=f.readlines()
    for line in data:
        print(line,end=" ")
    f.close()
        
def remove_contact(filename,name):
    with open(filename,'r+') as f:
        data=f.readlines()
        f.seek(0)
        for line in data:
            if name not in line:
                f.write(line)
    
def update_contact(filename,name):
    with open(filename,'r') as f:
        data=f.readlines()
        f.seek(0)
        k=0
        for line in data:
            if name in line:
                remove_contact(filename,name)
                new_name=input("Enter new name  ")
                phone=int(input("Enter Phone number  "))
                email=input("Enter email address  ")
                
                add_contact(new_name,phone,email)
                print("Cotnact updated")
                k=1
            
        if k==0:
            print("Contact Not updated please check it")
            
filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
c=1
while c==1:
    print("1.Add Contact\n2.Delete contact\n3.List of Contacts\n4.Search contact\n5.Update Contact list\n")
    value=int(input())
    if value==1:
        name=input("Enter name to add  ")
        phone=int(input("enter phone number to add  "))
        email=input("Enter email address  ")
        add_contact(name,phone,email)
    elif value==2:
        name=input("Enter name to delete a contact  ")
        remove_contact(filename,name)
    elif value==3:
        list_of_contacts(filename)
    elif value==4:
        name=input("Enter name to search  ")
        search_contact(name)
    elif value==5:
        name=input("Enter name to update contact list  ")
        update_contact(filename,name)
    print("\nenter 1 to continue\nEnter 0 to exit\t")
    c=int(input())

# %%
import re
def mail_validator(mail):
    pattern='^[a-zA-Z0-9][0-9a-zA-Z_.]{5,14}[0-9a-zA-Z](@)[0-9a-zA-Z]{2,15}(.)[a-z]{2,4}'
    if re.match(pattern,mail):
        return True
    else:
        return False
    
def PhoneNumber_validator(number):
    pattern='^[6-9][0-9]{9}$|^[+][9][1][6-9][0-9]{9}$|^[0][6-9][0-9]{9}$'
    if re.match(pattern,number):
        return True
    else:
        return False


def add_contact(name,phone,email):
    #store datas name, phone,email in the contact text file
    filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
    if not checkContactExists(name):
        p=phone.__str__()
        if PhoneNumber_validator(p)==True and mail_validator(email)==True:
            with open(filename,'a') as f:
                line=name+','+str(phone)+','+email+"\n"
                f.write(line)
        print(name,'added to contact list')
    else:
        print(name,'already exists')
    return

#Function to check if contact already exists
def checkContactExists(name):
    filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
    with open(filename,'r') as f:
        data=f.read()
        pattern=name+','
    print(re.search(pattern,data))
    return re.search(name,data)



def search(filename,name):
    with open(filename,'r')as f:
        lines=f.readlines()
        pattern=name+","
        for name in lines:
            if re.search(pattern,name):
                print(name)
def delete_contact(filename,name):
    with open(filename,'r+') as f:
        data=f.readlines()
        f.seek(0)
        for line in data:
            if name not in line:
                f.write(line)
        f.truncate()
    print("\nContact Successfully deleted\n")
        
def list_of_contacts(filename):
    print("\tName\tPhone num\tmail")
    with open(filename,'r') as f:
        data=f.readlines()
        for line in data:
            l=line.split(",")
            for i in range(0,len(l),1):
                print("\t",l[i],end="")

def update_contact(filename,name):
    j=0
    with open(filename,'r') as f:
        data=f.readlines()
        f.seek(0)
        for line in data:
            if name in line:
                delete_contact(filename,name)
                
                new_name=input("Enter new name  ")
                phone=int(input("Enter Phone number  "))
                email=input("Enter email address  ")
                
                add_contact(new_name,phone,email)
                j=1
                print("Cotnact updated")
    if j!=1:
        print("\nTheir is no such contact exist.Please check the name\n")
    
    
c=1
filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/contacts.txt"
while c==1:
    print("\n1.Add contact\n2.list of contacts\n3.Delete contact\n4.search for a contact\n5.Update a contact")
    value=int(input())
    if value==1:
        name=input("Etner name to add  ")
        phone=int(input("Etner phone number  "))
        email=input("Etner email address  ")
        add_contact(name,phone,email)
    elif value==2:
        list_of_contacts(filename)
    elif value==3:
        name=input("Etner name to delete ")
        delete_contact(filename,name)
    elif value==4:
        name=input("Enter name to search for a contact")
        search(filename,name)
    elif value==5:
        name=input("Etner name to update contact info ")
        update_contact(filename,name)
        
    print("\nEnter 1 to continue\nEtner 0 to exit\n") 
    c=int(input())
# Out:
# 1.Add contact
# 2.list of contacts
# 3.Delete contact
# 4.search for a contact
# 5.Update a contact
# 1
# Etner name to add  nani
# Etner phone number  9160298637
# Etner email address  nani123@gmail.com
# None
# nani added to contact list
#
# Enter 1 to continue
# Etner 0 to exit
#
# 1
#
# 1.Add contact
# 2.list of contacts
# 3.Delete contact
# 4.search for a contact
# 5.Update a contact
# 2
# 	Name	Phone num	mail
# 	 roja	 9133892252	 mogiliroja@gmail.com
# 	 lally	 9581170037	 lally1234@gmail.com
# 	 nani	 9160298637	 nani123@gmail.com
#
# Enter 1 to continue
# Etner 0 to exit
#
# 1
#
# 1.Add contact
# 2.list of contacts
# 3.Delete contact
# 4.search for a contact
# 5.Update a contact
# 3
# Etner name to delete lally
#
# Contact Successfully deleted
#
#
# Enter 1 to continue
# Etner 0 to exit
#
# 1
#
# 1.Add contact
# 2.list of contacts
# 3.Delete contact
# 4.search for a contact
# 5.Update a contact
# 2
# 	Name	Phone num	mail
# 	 roja	 9133892252	 mogiliroja@gmail.com
# 	 nani	 9160298637	 nani123@gmail.com
#
# Enter 1 to continue
# Etner 0 to exit
