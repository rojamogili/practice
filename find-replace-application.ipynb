# %% [markdown]
# - Find and replace application

# %%
# Find and replace application

def unique_word_count(filename,word):
    c=0
    with open(filename,'r') as f:
        for line in f:
            words=line.split(" ")
            for i in range(0,len(words),1):
                if words[i]==word or words[i]==word+"\n":
                    c=c+1
    print("We have ",c,"words to replace")
    return c
    
def replace_word(filename,word,rword):
    with open(filename,'r+') as f:
        data=f.readlines()
        f.seek(0)
        for line in data:
            if word not in line:
                f.write(line)
                #print(line)
            else:
                s=line.split()
                for j in range(0,len(s),1):
                    if word==s[j]:
                        s[j]=rword
                s=" ".join(s)
                #print(s)
                f.write(s+"\n")
        f.truncate()
    print("\nSuccessfully replaced\n")
        

filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/data.txt"
word=input("Enter the word which you want to remove ")
unique_word_count(filename,word)
rword=input("enter the new word")
replace_word(filename,word,rword)
# Out:
# Enter the word which you want to remove nani
# We have  3 words to replace
# enter the new wordlally
#
# Successfully replaced

# %%
s=["roja","nani","lally"]
" ".join(s)
# Out:
# 'roja nani lally'
