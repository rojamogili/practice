# %% [markdown]
# ### working with random numbers and files
# - % of students passed
# - % of students failed
# - % of students with distinction
# - % of average
# - no. of students who got low marks
# - no. of students who got high marks

# %%
from random import randint
def generatemarks(n,lb,ub):
    for i in range(0,n,1):
        r=randint(lb,ub)
        f.write(r.__str__()+" ")
def average_percentage(marks):
    count=0
    for i in range(0,len(marks),1):
        count+=marks[i]
    print("Average percentage is ",(count//len(marks)))

def passed_percentage(filename,marks):
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]>=Passmarks:
            count+=1
    print("Pass percentage is ",int((count/n)*100),"%")
    
def failed_percentage(filename,marks):
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]<Passmarks:
            count+=1
    print("fail percentage is ",int((count/n)*100),"%")

        
def distinction(filename,marks):
    count=0
    dist=int(input("Enter distinction marks lower bound  "))
    for i in range(0,len(marks),1):
        if marks[i]>=dist:
            count+=1
    print("distinction percentage is ",int((count/n)*100),"%")
    
def high_mark(marks):
    high=max(marks)
    count=0
    for i in range(0,len(marks),1):
        if marks[i]==high:
            count+=1
    print("Highest marks is ",high," number of persons got high",count)

def low_mark(marks):
    m=min(marks)
    count=0
    for i in range(0,len(marks),1):
        if marks[i]==m:
            count+=1
    print("Lowest marks is ",m," number of persons got low marks",count)
    

filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/marks.txt"
n=int(input("Enter how many student marks u want to generate "))
with open(filename,'r+') as f:
    generatemarks(n,0,100)
    
with open(filename,'r') as f:
    data=f.read()
    m=data.split(" ")
    marks=[]
    for i in range(0,len(m),1):
        marks=marks+[int(m[i])]
c=1
while c==1:
    print("\n1.List of marks\n2.Pass percentage\n3.Failed percentage\n4.Distinction percentage\n5.High marks\n6.Low mark\n7.Average percentage\n")
    value=int(input())
    if value==1:
        for i in range(0,len(marks),1):
            print(marks[i],end=" ")
        
    elif value==2:
        passed_percentage(filename,marks)
    elif value==3:
        failed_percentage(filename,marks)
    elif value==4:
        distinction(filename,marks)
    elif value==5:
        high_mark(marks)
    elif value==6:
        low_mark(marks)
    elif value==7:
        average_percentage(marks)
    else:
        print("\nWrong input.Please enter correct input\n")

    print("\nEnter 1 to continue\nEnter 0 to exit\n")
    c=int(input())
# Out:
# Enter how many student marks u want to generate 100
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
# 7.Average percentage
#
# 7
# Average percentage is  48
#
# Enter 1 to continue
# Enter 0 to exit
#
# 1
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
# 7.Average percentage
#
# 1
# 80 43 87 67 57 35 14 84 58 71 47 45 60 11 77 92 5 55 53 14 95 84 17 86 67 1 44 61 39 3 9 33 43 23 8 52 27 93 89 37 5 53 3 29 58 90 10 100 63 37 40 84 4 56 89 28 85 10 42 63 14 78 59 21 37 55 34 87 14 2 93 22 96 3 22 93 38 37 76 84 37 95 39 42 66 38 80 35 22 75 77 77 40 94 25 38 16 44 51 84 4 3 49
# Enter 1 to continue
# Enter 0 to exit
#
# 1
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
# 5.High marks
# 6.Low mark
# 7.Average percentage
#
# 5
# Highest marks is  100  number of persons got high 1
#
# Enter 1 to continue
# Enter 0 to exit
#
# 0

# %%
from random import randint
def generatemarks(n,lb,ub):
    r=randint(lb,ub)
    f.write(r.__str__())
    for i in range(0,n-1,1):
        r=randint(lb,ub)
        f.write(" "+r.__str__())
        
def list_of_marks(filename):
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")
        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    print(marks)
    
def passed_percentage(filename):
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")

        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    count=0
    
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]>=Passmarks:
            count+=1
    print("Pass percentage is ",int((count/n)*100),"%")
def failed_percentage(filename):
    
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")

        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]<Passmarks:
            count+=1
    print("fail percentage is ",int((count/n)*100),"%")

        
def distinction(filename):
    with open(filename,'r') as f:
        data=f.read()
        m=data.split(" ")

        marks=[]
        for i in range(0,len(m),1):
            marks=marks+[int(m[i])]
    count=0
    dist=int(input("Enter distinction marks lower bound  "))
    for i in range(0,len(marks),1):
        if marks[i]>=dist:
            count+=1
    print("distinction percentage is ",int((count/n)*100),"%")
    
filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/marks.txt"
n=int(input("Enter how many student marks u want to geenrate "))
with open(filename,'r+') as f:
    generatemarks(n,0,100)
c=1
while c==1:
    print("\n1.List of marks\n2.Pass percentage\n3.Failed percentage\n4.Distinction percentage\n")
    value=int(input())
    if value==1:
        list_of_marks(filename)
    elif value==2:
        passed_percentage(filename)
    elif value==3:
        failed_percentage(filename)
    elif value==4:
        distinction(filename)
    else:
        print("\nWrong input.Please enter correct input\n")

    print("\nEnter 1 to continue\nEnter 0 to exit\n")
    c=int(input())

print(len(marks))
# Out:
# Enter how many student marks u want to geenrate 100
#
# 1.List of marks
# 2.Pass percentage
# 3.Failed percentage
# 4.Distinction percentage
#
# 2
# Enter pass marks  35
# Pass percentage is  71 %
#
# Enter 1 to continue
# Enter 0 to exit
#
# 0
# 100

# %% [markdown]
# ##

# %%
from random import randint
def generatemarks(n,lb,ub):
    for i in range(0,n,1):
        r=randint(lb,ub)
        f.write(r.__str__()+" ")
def average_percentage(marks):
    count=0
    for i in range(0,len(marks),1):
        count+=marks[i]
    print("Average percentage is ",(count//len(marks)))

def passed_percentage(filename,marks):
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]>=Passmarks:
            count+=1
    print("Pass percentage is ",int((count/n)*100),"%")
    
def failed_percentage(filename,marks):
    count=0
    Passmarks=int(input("Enter pass marks  "))
    for i in range(0,len(marks),1):
        if marks[i]<Passmarks:
            count+=1
    print("fail percentage is ",int((count/n)*100),"%")

        
def distinction(filename,marks):
    count=0
    dist=int(input("Enter distinction marks lower bound  "))
    for i in range(0,len(marks),1):
        if marks[i]>=dist:
            count+=1
    print("distinction percentage is ",int((count/n)*100),"%")
    
def high_mark(marks):
    high=max(marks)
    count=0
    for i in range(0,len(marks),1):
        if marks[i]==high:
            count+=1
    print("Highest marks is ",high," number of persons got high",count)

def low_mark(marks):
    m=min(marks)
    count=0
    for i in range(0,len(marks),1):
        if marks[i]==m:
            count+=1
    print("Lowest marks is ",m," number of persons got low marks",count)
    

filename="C:/Users/IIIT-rgukt/Desktop/python_basics_apssdc/jupyter/marks.txt"
n=int(input("Enter how many student marks u want to generate "))
with open(filename,'r+') as f:
    generatemarks(n,0,100)
    
with open(filename,'r') as f:
    data=f.read()
    m=data.split(" ")
    marks=list(map(int,data.split(" ")))
c=1
while c==1:
    print("\n1.List of marks\n2.Pass percentage\n3.Failed percentage\n4.Distinction percentage\n5.High marks\n6.Low mark\n7.Average percentage\n")
    value=int(input())
    if value==1:
        for i in range(0,len(marks),1):
            print(marks[i],end=" ")
        
    elif value==2:
        passed_percentage(filename,marks)
    elif value==3:
        failed_percentage(filename,marks)
    elif value==4:
        distinction(filename,marks)
    elif value==5:
        high_mark(marks)
    elif value==6:
        low_mark(marks)
    elif value==7:
        average_percentage(marks)
    else:
        print("\nWrong input.Please enter correct input\n")

    print("\nEnter 1 to continue\nEnter 0 to exit\n")
    c=int(input())
# Out:
# Enter how many student marks u want to generate 100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-eb9668aacbfb> in <module>
#      60     data=f.read()
#      61     m=data.split(" ")
# ---> 62     marks=list(map(int,data.split(" ")))
#      63 c=1
#      64 while c==1:
#
# ValueError: invalid literal for int() with base 10: ''
